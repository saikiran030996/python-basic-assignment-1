# %% [markdown]
# # Assignment-1

# %% [raw]
# 1. What are the differences between operators and values in the following?
# * - operator
# 'hello' - value
# / - operator
# + - operator
# 6 - value
# -87.8 - value
# - - operator

# %% [raw]
# 2. What is the difference between string and variable?
# spam - variable
# 'spam' - string

# %% [raw]
# 3. Describe three different data forms.
# string - 'saikiran'
# integer - 1,2,3
# float - 1.2

# %%
# code regarding 3rd question to check whether the given varaible is which form of the data

print(type('saikiran'))
print(type(1))
print(type(1.2))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [raw]
# 4. What makes up an expression? What are the functions of all expressions?
# Ans. group of charaters makes up an expression

# %% [raw]
# 5. In this chapter, assignment statements such as spam = 10 were added. What's the difference between a declaration and an expression?
# Ans. spam = 10 is a declaration
# group of decalarations operands and characters is called an expression

# %% [raw]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
# variable bacon contain 21

# %%
bacon = 20
bacon+1
# Out:
# 21

# %% [raw]
# 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
# 'spam' * 3
# 'spamspamspam'
# 'spamspamspam'

# %%
print('spam'+'spamspam')
print('spam'*3)
# Out:
# spamspamspam
# spamspamspam

# %%
'spam' + 'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam' *3
# Out:
# 'spamspamspam'

# %% [raw]
# 8. Why is it that eggs is a true variable name but 100 is not?
# Ans. According to python variable declaration rules the declaration should start with a alphabet not an numerical in this case.

# %%
eggs = 100
eggs
# Out:
# 100

# %%
100 = eggs
# Out:
#   File "<ipython-input-10-235f62072e11>", line 1
#     100 = eggs
#               ^
# SyntaxError: can't assign to literal

# %% [raw]
# 10. What is the error caused by this expression? What would you do about it?
#
# 'I have eaten ' + 99 + ' burritos.'
# Ans. string cannot concatenate with a numerical data type

# %%
print('I have eaten'+ 99 + 'burritos')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-4216e5136a82> in <module>
# ----> 1 print('I have eaten'+ 99 + 'burritos')
#
# TypeError: can only concatenate str (not "int") to str
